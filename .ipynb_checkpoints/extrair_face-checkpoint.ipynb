# %%
pip install mtcnn tensorflow pillow
# Out:
# Requirement already satisfied: mtcnn in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (1.0.0)
# Requirement already satisfied: tensorflow in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (2.18.0)
# Collecting pillow
#   Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from mtcnn) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from mtcnn) (4.4.3)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\vitor\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.0.1)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\vitor\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.1)
# Requirement already satisfied: namex in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vitor\anaconda3\envs\ambiente-1\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vitor\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 18.9 MB/s eta 0:00:00
# Installing collected packages: pillow
# Successfully installed pillow-11.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from mtcnn import MTCNN
from PIL import Image
from numpy import asarray

# %%
detector = MTCNN()

# %%
def extract_face(file, size=(160,160)):

  img = Image.open(file) # caminho completo

  img = img.convert('RGB')

  array = asarray(img)

  results = detector.detect_faces(array)

  if results:
    x1, y1, width, height = results[0]['box']

    x2, y2 = x1 + width, y1 + height

    face = array[y1:y2, x1:x2]

    image = Image.fromarray(face)
    image = image.resize(size)

    return image
  else:
    print(f"No faces detected in {file}. Skipping...")
    return None

  return image

def flip_image(image):
  img = image.transpose(Image.FLIP_LEFT_RIGHT)
  return img


def load_fotos(directory_src, directory_target):

  for filename in os.listdir(directory_src):
    if filename == '.ipynb_checkpoints':
      continue

    path = directory_src + filename
    path_target = directory_target + filename

    # Create target directory if it doesn't exist
    target_dir = os.path.dirname(path_target) # Extract directory from path_target
    os.makedirs(target_dir, exist_ok=True)    # Create directory if it doesn't exist

    path_target_flip = directory_target + "flip_" + filename

    face = extract_face(path)

    flip_face = flip_image(face)

    if face:
        face.save(path_target)
        flip_face.save(path_target_flip)



def load_dir(directory_src, directory_target):

  for subdir in os.listdir(directory_src):
    if subdir == '.ipynb_checkpoints':
      continue

    path = directory_src + "/" + subdir + "/"

    path_target = directory_target + "/" + subdir + "/"

    if not os.path.isdir(path):
      continue

    load_fotos(path, path_target)

# %%
load_dir("C:\\Users\\Vitor\\Estudos\\Reconhecimento Facial\\fotos",
         "C:\\Users\\Vitor\\Estudos\\Reconhecimento Facial\\faces")
